# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ### Camila Teixeira

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.7

# %% [markdown]
# ### Gráficos

# %%
# Instala a versão exata do pacote matplotlib
# !pip install matplotlib

# %%
import matplotlib as mat
mat.__version__
# Out:
# '3.4.3'

# %%
import sqlite3
import random
import datetime
import matplotlib.pyplot as plt
# %matplotlib notebook
 
# Criando uma conexão
conn = sqlite3.connect('loja3.db')   

# Criando um cursor
c = conn.cursor()
 
# Função para criar uma tabela
def create_table():
    c.execute('CREATE TABLE IF NOT EXISTS produtos(id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, date DATETIME, '\
              'prod_name TEXT, valor REAL)')
     
# Função para inserir uma linha
def data_insert():
    c.execute("INSERT INTO produtos (date, prod_name, valor) VALUES(time(), 'Teclado', 130 )")
    
# Usando variáveis para inserir dados    
def data_insert_var():
    new_date = datetime.datetime.now()
    new_prod_name = 'monitor'
    new_valor = random.randrange(50,100)
    c.execute("INSERT INTO produtos (date, prod_name, valor) VALUES (?, ?, ?)", 
              (new_date, new_prod_name, new_valor))
    conn.commit()
    
# Leitura de dados
def leitura_todos_dados():
    c.execute("SELECT * FROM PRODUTOS")
    for linha in c.fetchall():
        print(linha)
        
# Leitura de registros específicos
def leitura_registros():
    c.execute("SELECT * FROM PRODUTOS WHERE valor > 60.0")
    for linha in c.fetchall():
        print(linha)      
        
# Leitura de colunas específicos
def leitura_colunas():
    c.execute("SELECT * FROM PRODUTOS")
    for linha in c.fetchall():
        print(linha[3])  
        
# Update
def atualiza_dados():
    c.execute("UPDATE produtos SET valor = 70.00 WHERE valor > 80.0")
    conn.commit()
    
# Delete
def remove_dados():
    c.execute("DELETE FROM produtos WHERE valor = 62.0")
    conn.commit()

        
# Gerar gráfico com os dados no banco de dados
def dados_grafico():
    c.execute("SELECT id, valor FROM produtos")
    ids = []
    valores = []
    dados = c.fetchall()
    for linha in dados:
        ids.append(linha[0])
        valores.append(linha[1])
        
    plt.bar(ids, valores)
    plt.show()

# %%
# Criar tabela
create_table()

# %%
# Inserir dados
data_insert()

# %%
# Usando variáveis para inserir dados 
data_insert_var()

# %%
# Select nos dados
leitura_todos_dados()
# Out:
# (1, '22:19:27', 'Teclado', 130.0)
# (2, '2022-07-11 19:19:28.697355', 'monitor', 64.0)

# %%
# Leitura de registros específicos
leitura_registros()
# Out:
# (1, '22:19:27', 'Teclado', 130.0)
# (2, '2022-07-11 19:19:28.697355', 'monitor', 64.0)

# %%
# Leitura de colunas específicas
leitura_colunas()
# Out:
# 130.0
# 64.0

# %%
atualiza_dados()

# %%
leitura_todos_dados()
# Out:
# (1, '22:19:27', 'Teclado', 70.0)
# (2, '2022-07-11 19:19:28.697355', 'monitor', 64.0)

# %%
remove_dados()

# %%
leitura_todos_dados()
# Out:
# (1, '22:19:27', 'Teclado', 70.0)
# (2, '2022-07-11 19:19:28.697355', 'monitor', 64.0)

# %%
# Gerando gráficos
dados_grafico()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Encerrando a conexão
c.close()
conn.close()

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado
#
# ### Visite o Blog da Data Science Academy - <a href="http://blog.dsacademy.com.br">Blog DSA</a>
